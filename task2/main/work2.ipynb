# %%
import os
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import transforms
import torch.optim as optim
import time

CIFAR_URL = 'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz'

# %%
def downloadCIFAR():
    if not os.path.exists('../data'):
        os.system('mkdir ../data')
        print('make dir')
    if not os.path.exists('../data/cifar-10-python.tar.gz'):
        print('downloading CIFAR')
        os.system('wget {}'.format(CIFAR_URL))
        os.system('mv ./cifar-10-python.tar.gz ../data/cifar-10-python.tar.gz')
    else:
        print('CIFAR exist')
    if not os.path.exists('../data/cifar-10-batches-py'):
        print('unpacking CIFAR')
        os.system('tar -zxvf ../data/cifar-10-python.tar.gz -C ../data/')
    else:
        print('CIFAR unpacked')

downloadCIFAR()
# Out:
# downloading CIFAR
# CIFAR unpacked

# %%
import matplotlib.pyplot as plt

def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict


def show_img(num):
    dict = unpickle('../data/cifar-10-batches-py/data_batch_1')
    info = unpickle('../data/cifar-10-batches-py/batches.meta')
    np_img = dict[b'data'][num].reshape([3, 32, 32])
    np_img = np_img.transpose(1, 2, 0)
    label = info[b'label_names'][dict[b'labels'][num]]

    plt.imshow(np_img)
    plt.axis('on')
    plt.title(label)
    plt.show()


show_img(6)

# %%
def get_label_data(train_val, num=0):
    if train_val == 'train':
        dict = unpickle('../data/cifar-10-batches-py/data_batch_{}'.format(num))
        return torch.tensor(dict[b'labels'], dtype=torch.long), torch.tensor(dict[b'data'],
                                                                                dtype=torch.float32).reshape(10000, 3, 32, 32)
    else:
        dict = unpickle('../data/cifar-10-batches-py/test_batch')
        return torch.tensor(dict[b'labels'], dtype=torch.long), torch.tensor(dict[b'data'],
                                                                                dtype=torch.float32).reshape(10000, 3, 32, 32)

def load_data():
    for i in range(5):
        if i == 0:
            train_labels, train_data = get_label_data('train', i + 1)
        else:
            res = get_label_data('train', i + 1)
            train_labels = torch.concat((train_labels, res[0]), dim=0)
            train_data = torch.concat((train_data, res[1]), dim=0)
    test_labels, test_data = get_label_data('test')
    return train_labels, train_data, test_labels, test_data

train_labels, train_data, test_labels, test_data = load_data()
print(train_labels.shape, train_data.shape, test_labels.shape, test_data.shape)
# Out:
# torch.Size([50000]) torch.Size([50000, 3, 32, 32]) torch.Size([10000]) torch.Size([10000, 3, 32, 32])

# %%
# 数据预处理
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

train_data = torch.stack([transform(img) for img in train_data])
test_data = torch.stack([transform(img) for img in test_data])

# %% [markdown]
# # 自定义训练

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
#定义网络模型
class BasicBlock(nn.Module):  #定义BasicBlock类
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):   #构造函数，初始化对象（输入通道数、输出通道数、步长）
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False) #定义第一个卷积层
        self.bn1 = nn.BatchNorm2d(planes)  #批量归一化层
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False) #定义第二个卷积层
        self.bn2 = nn.BatchNorm2d(planes)  #批量归一化层

        self.shortcut = nn.Sequential()  #初始化空顺序容器，实现残差连接
        if stride != 1 or in_planes != self.expansion*planes: #如果步长不为 1 或者输入通道数与输出通道数不匹配，则需要修改 shortcut
            self.shortcut = nn.Sequential( #重新定义 shortcut，包含一个卷积层和一个批量归一化层。
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):  #定义前向传播函数
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet(nn.Module):  #定义残差网络模型
    def __init__(self, block, num_blocks, num_classes=10):  #构造函数，（基本块、每个残差层的块数、输出类别数量）
        super(ResNet, self).__init__()
        self.in_planes = 64  #初始化输入通道数

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False) #定义卷积层
        self.bn1 = nn.BatchNorm2d(64)  #批量归一化层
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) #定义四个残差层，每个层由多个block组成
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)  #全连接层

    def _make_layer(self, block, planes, num_blocks, stride):  #创建由多个block组成的残差层
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:  #循环创建每个块
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)  #返回包含所有块的顺序容器

    def forward(self, x):  #前向传播
        out = F.relu(self.bn1(self.conv1(x)))  #应用Relu激活函数
        out = self.layer1(out) #依次通过四个残差层
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)  #应用平均池化减小空间维度
        out = out.view(out.size(0), -1)
        out = self.linear(out)  #全连接层
        return out


# 定义ResNet-18
num_blocks = [2, 2, 2, 2]  # ResNet-18的结构
model = ResNet(BasicBlock, num_blocks, num_classes=10)  #实例化网络模型

# %%
criterion = nn.CrossEntropyLoss()

# %%
# import torch
# import torch.nn.functional as F
# def criterion(outputs, targets):  #定义损失函数
#     # 转换 targets 为 one-hot 编码
#     batch_size = outputs.size(0)   #获取批次大小和类别数
#     num_classes = outputs.size(1)
#     targets_one_hot = torch.zeros(batch_size, num_classes).to(outputs.device)
#     targets_one_hot.scatter_(1, targets.view(-1, 1), 1)

#     # 计算 log-softmax
#     log_probs = F.log_softmax(outputs, dim=1)   #得到每个类别的对数概率

#     # 计算负对数似然损失
#     loss = -torch.sum(log_probs * targets_one_hot, dim=1)
#     loss = torch.mean(loss)

#     return loss   #返回损失值

# %%
# class SimpleSGD:    #定义优化器类
#     def __init__(self, params, lr=0.001):   #构造函数，初始化模型参数列表和学习率
#         self.params = list(params)
#         self.lr = lr

#     def zero_grad(self):  #清零参数的梯度
#         for param in self.params:
#             if param.grad is not None:
#                 param.grad.data.zero_()

#     def step(self):   #执行一步参数更新
#         with torch.no_grad():
#             for param in self.params:
#                 if param.grad is not None:
#                     param.data -= self.lr * param.grad.data

# %%
# optimizer = SimpleSGD(model.parameters(), lr=0.001)  #定义优化器

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

def train(model, device, train_loader, optimizer, epoch, criterion): #定义训练函数
    model.train()  #用于训练的模型，设置模型为训练模式
    running_loss = 0.0 #初始化损失和准确率的累计变量
    corrects = 0
    total = 0
    for batch_idx, (data, target) in enumerate(train_loader):#遍历数据加载器的每个批次
        data, target = data.to(device), target.to(device) #将数据和标签移动到指定设备
        optimizer.zero_grad() #梯度清空
        output = model(data)  #前向传播得到输出
        loss = criterion(output, target) #计算损失
        loss.backward()  #反向传播计算梯度
        optimizer.step()  #更新模型参数

        # 计算并累计准确率
        _, preds = torch.max(output, 1)
        corrects += torch.sum(preds == target.data)
        total += target.size(0)

        running_loss += loss.item() * data.size(0)  #累计损失

        # 只在batch_idx不为0且是100的倍数时打印
        if batch_idx != 0 and batch_idx % 100 == 0:
            avg_loss = running_loss / (batch_idx * data.size(0))  #打印损失和准确率
            acc = 100. * corrects / total
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}\tAcc: {:.2f}%'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), avg_loss, acc))
            running_loss = 0.0  #清零。重新累计
            corrects = 0
            total = 0

    return avg_loss, acc

# 假设有CUDA 设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)  #将模型移动到指定的设备

# 初始化列表来存储每个epoch的损失和准确率
train_losses = []
train_accs = []

# 训练模型
num_epochs = 5  #设置训练轮数

for epoch in range(1, num_epochs + 1): #遍历每个epoch
    avg_loss, acc = train(model, device, DataLoader(TensorDataset(train_data, train_labels), batch_size=64, shuffle=True), optimizer, epoch, criterion)
    train_losses.append(avg_loss) #调用train函数进行训练，获取平均损失和准确率并添加到对应列表
    train_accs.append(acc)

# 保存模型
torch.save(model.state_dict(), 'model.pth')
# Out:
# Train Epoch: 1 [6400/50000 (13%)]	Loss: 1.843563	Acc: 32.61%
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 0.775608	Acc: 42.47%
# Train Epoch: 1 [19200/50000 (38%)]	Loss: 0.452717	Acc: 49.77%
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.317131	Acc: 54.44%
# Train Epoch: 1 [32000/50000 (64%)]	Loss: 0.234188	Acc: 58.11%
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.184367	Acc: 60.20%
# Train Epoch: 1 [44800/50000 (90%)]	Loss: 0.149384	Acc: 62.98%
# Train Epoch: 2 [6400/50000 (13%)]	Loss: 0.910730	Acc: 68.13%
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.433537	Acc: 68.94%
# Train Epoch: 2 [19200/50000 (38%)]	Loss: 0.281522	Acc: 70.20%
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.201256	Acc: 71.95%
# Train Epoch: 2 [32000/50000 (64%)]	Loss: 0.159432	Acc: 72.33%
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.124074	Acc: 73.66%
# Train Epoch: 2 [44800/50000 (90%)]	Loss: 0.103693	Acc: 74.31%
# Train Epoch: 3 [6400/50000 (13%)]	Loss: 0.619467	Acc: 78.60%
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.314132	Acc: 78.77%
# Train Epoch: 3 [19200/50000 (38%)]	Loss: 0.201810	Acc: 78.95%
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.150624	Acc: 78.92%
# Train Epoch: 3 [32000/50000 (64%)]	Loss: 0.118949	Acc: 78.94%
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.099045	Acc: 79.20%
# Train Epoch: 3 [44800/50000 (90%)]	Loss: 0.082892	Acc: 79.88%
# Train Epoch: 4 [6400/50000 (13%)]	Loss: 0.455449	Acc: 83.96%
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.235212	Acc: 83.61%
# Train Epoch: 4 [19200/50000 (38%)]	Loss: 0.158433	Acc: 83.88%
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.118377	Acc: 83.53%
# Train Epoch: 4 [32000/50000 (64%)]	Loss: 0.095441	Acc: 83.11%
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.076428	Acc: 84.08%
# Train Epoch: 4 [44800/50000 (90%)]	Loss: 0.066319	Acc: 84.39%
# Train Epoch: 5 [6400/50000 (13%)]	Loss: 0.338087	Acc: 88.30%
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.188757	Acc: 86.52%
# Train Epoch: 5 [19200/50000 (38%)]	Loss: 0.125223	Acc: 86.88%
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.088312	Acc: 87.97%
# Train Epoch: 5 [32000/50000 (64%)]	Loss: 0.069722	Acc: 87.98%
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.061164	Acc: 87.36%
# Train Epoch: 5 [44800/50000 (90%)]	Loss: 0.053319	Acc: 87.12%

# %% [markdown]
# # 尝试绘制loss和acc的图像

# %%
# 确保train_losses和train_accs中的值是CPU张量或数值
train_accs = [acc.item() for acc in train_accs]
# 训练结束后绘制曲线
plt.figure(figsize=(10, 5))  #创建窗口并规定图像大小

# 绘制损失曲线
plt.subplot(1, 2, 1)  #创建子图网格
plt.plot(train_losses, label='Training Loss') #绘制训练损失曲线
plt.title('Training Loss over Epochs') #子图标题
plt.xlabel('Epoch')  #X轴标签
plt.ylabel('Loss')   #Y轴标签
plt.legend()  #显示图例

# 绘制准确率曲线
plt.subplot(1, 2, 2)
plt.plot(train_accs, label='Training Accuracy')
plt.title('Training Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# 显示图形
plt.tight_layout()
plt.show()

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import torch
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset

losses1 = []  # 记录每个批次的损失
accuracies1 = []  # 记录每个批次的准确率

def test(model, device, test_loader, output_file):
    model.eval()  # 设置模型为评估模式
    test_loss = 0  # 初始化用于记录测试损失、正确预测数和总样本数的变量
    correct = 0
    total = 0
    preds = []
    
   

    # 记录每个类别的正确预测数和总样本数
    correct_per_class = [0] * 10  # 假设有10个类别
    total_per_class = [0] * 10
    
    with torch.no_grad():  # 不需要计算梯度
        for batch_idx, (data, target) in enumerate(test_loader):  # 遍历每个批次的数据
            data, target = data.to(device), target.to(device)  # 将数据转移到指定设备上
            output = model(data)  # 模型预测得到输出
            loss = criterion(output, target)  # 计算损失
            test_loss += loss.item()  # 累加损失
            
            # 计算批次的准确率
            _, predicted = torch.max(output, 1)  # 获取预测结果
            preds.extend([classes[i] for i in predicted.cpu().numpy()])  # 将预测类别转换为类别标签字符串，并添加到preds列表中
            
            total += target.size(0)  # 累加样本总数
            correct += (predicted == target).sum().item()  # 统计正确预测的样本数

            # 更新每个类别的正确预测数和总样本数
            for i in range(len(target)):
                label = target[i].item()
                correct_per_class[label] += (predicted[i] == target[i]).item()
                total_per_class[label] += 1
            
            # 计算每个批次的损失和准确率
            batch_loss = loss.item()
            batch_accuracy = 100 * (predicted == target).sum().item() / target.size(0)
            losses1.append(batch_loss)
            accuracies1.append(batch_accuracy)
            
            # 打印每个批次的损失和准确率
            print(f'Batch {batch_idx + 1}: Loss: {batch_loss:.4f}, Accuracy: {batch_accuracy:.2f}%')
    
    # 创建DataFrame并保存为CSV文件
    sorted_ids = list(range(1, len(test_data) + 1))
    sorted_ids.sort(key=lambda x: str(x))
    df = pd.DataFrame({'id': sorted_ids, 'label': preds})  # 第一列是id，第二列是预测的类别
    df.to_csv(output_file, index=False)  # 保存为CSV文件，不包含索引

    # 计算平均损失和准确率
    avg_loss = test_loss / len(test_loader)
    accuracy = 100 * correct / total

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(  # 打印平均loss和准确率
        avg_loss, correct, total, accuracy))
    
    # 打印每个类别的准确率
    for i in range(len(correct_per_class)):
        class_accuracy = 100 * correct_per_class[i] / total_per_class[i] if total_per_class[i] > 0 else 0
        print(f'Class {i}: Accuracy: {class_accuracy:.2f}%')

    # 绘制损失和准确率曲线
    plt.figure(figsize=(12, 5))
    
    # 绘制损失曲线
    plt.subplot(1, 2, 1)
    plt.plot(losses1, label='Loss', color='blue')
    plt.xlabel('Batch')
    plt.ylabel('Loss')
    plt.title('Loss Curve')
    plt.legend()
    
    # 绘制准确率曲线
    plt.subplot(1, 2, 2)
    plt.plot(accuracies1, label='Accuracy', color='orange')
    plt.xlabel('Batch')
    plt.ylabel('Accuracy (%)')
    plt.title('Accuracy Curve')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# 创建DataLoader
test_loader = DataLoader(TensorDataset(test_data, test_labels), batch_size=64, shuffle=False)

# 创建模型实例并加载训练好的模型
model = ResNet(BasicBlock, num_blocks, num_classes=10)
model.load_state_dict(torch.load('model.pth'))
model.to(device)

# 测试模型并绘制损失和准确率曲线
test(model, device, test_loader, 'submission.csv')
# Out:
# Batch 1: Loss: 0.7356, Accuracy: 78.12%
# Batch 2: Loss: 0.3182, Accuracy: 89.06%
# Batch 3: Loss: 0.5457, Accuracy: 82.81%
# Batch 4: Loss: 0.7761, Accuracy: 78.12%
# Batch 5: Loss: 0.5959, Accuracy: 78.12%
# Batch 6: Loss: 0.4558, Accuracy: 84.38%
# Batch 7: Loss: 0.7563, Accuracy: 78.12%
# Batch 8: Loss: 0.4400, Accuracy: 84.38%
# Batch 9: Loss: 0.4677, Accuracy: 87.50%
# Batch 10: Loss: 0.2333, Accuracy: 90.62%
# Batch 11: Loss: 0.5219, Accuracy: 79.69%
# Batch 12: Loss: 0.7466, Accuracy: 75.00%
# Batch 13: Loss: 0.7433, Accuracy: 70.31%
# Batch 14: Loss: 0.9766, Accuracy: 70.31%
# Batch 15: Loss: 0.5173, Accuracy: 85.94%
# Batch 16: Loss: 0.2855, Accuracy: 89.06%
# Batch 17: Loss: 0.7543, Accuracy: 84.38%
# Batch 18: Loss: 0.7553, Accuracy: 70.31%
# Batch 19: Loss: 0.5168, Accuracy: 84.38%
# Batch 20: Loss: 0.7220, Accuracy: 78.12%
# Batch 21: Loss: 0.5352, Accuracy: 76.56%
# Batch 22: Loss: 0.4719, Accuracy: 87.50%
# Batch 23: Loss: 0.4937, Accuracy: 78.12%
# Batch 24: Loss: 0.7749, Accuracy: 75.00%
# Batch 25: Loss: 0.6090, Accuracy: 75.00%
# Batch 26: Loss: 0.3970, Accuracy: 85.94%
# Batch 27: Loss: 0.6743, Accuracy: 85.94%
# Batch 28: Loss: 0.4967, Accuracy: 84.38%
# Batch 29: Loss: 0.4809, Accuracy: 82.81%
# Batch 30: Loss: 0.5595, Accuracy: 78.12%
# Batch 31: Loss: 0.9854, Accuracy: 71.88%
# Batch 32: Loss: 0.7000, Accuracy: 75.00%
# Batch 33: Loss: 0.5477, Accuracy: 82.81%
# Batch 34: Loss: 0.9673, Accuracy: 73.44%
# Batch 35: Loss: 0.6421, Accuracy: 79.69%
# Batch 36: Loss: 1.0033, Accuracy: 76.56%
# Batch 37: Loss: 0.7049, Accuracy: 79.69%
# Batch 38: Loss: 0.6636, Accuracy: 79.69%
# Batch 39: Loss: 0.5874, Accuracy: 79.69%
# Batch 40: Loss: 0.8517, Accuracy: 79.69%
# Batch 41: Loss: 0.4631, Accuracy: 85.94%
# Batch 42: Loss: 0.4760, Accuracy: 81.25%
# Batch 43: Loss: 0.5549, Accuracy: 85.94%
# Batch 44: Loss: 0.7941, Accuracy: 76.56%
# Batch 45: Loss: 0.5995, Accuracy: 84.38%
# Batch 46: Loss: 0.4287, Accuracy: 84.38%
# Batch 47: Loss: 0.5277, Accuracy: 78.12%
# Batch 48: Loss: 0.8891, Accuracy: 75.00%
# Batch 49: Loss: 0.5419, Accuracy: 82.81%
# Batch 50: Loss: 0.5141, Accuracy: 76.56%
# Batch 51: Loss: 0.5259, Accuracy: 79.69%
# Batch 52: Loss: 0.8454, Accuracy: 76.56%
# Batch 53: Loss: 0.7958, Accuracy: 73.44%
# Batch 54: Loss: 0.7766, Accuracy: 70.31%
# Batch 55: Loss: 0.6578, Accuracy: 78.12%
# Batch 56: Loss: 0.8003, Accuracy: 75.00%
# Batch 57: Loss: 0.8708, Accuracy: 73.44%
# Batch 58: Loss: 0.4624, Accuracy: 84.38%
# Batch 59: Loss: 0.6853, Accuracy: 79.69%
# Batch 60: Loss: 0.5893, Accuracy: 81.25%
# Batch 61: Loss: 0.4504, Accuracy: 84.38%
# Batch 62: Loss: 0.4900, Accuracy: 84.38%
# Batch 63: Loss: 0.6738, Accuracy: 82.81%
# Batch 64: Loss: 0.5526, Accuracy: 84.38%
# Batch 65: Loss: 0.7087, Accuracy: 78.12%
# Batch 66: Loss: 0.4673, Accuracy: 84.38%
# Batch 67: Loss: 0.5172, Accuracy: 78.12%
# Batch 68: Loss: 0.6570, Accuracy: 81.25%
# Batch 69: Loss: 0.3831, Accuracy: 82.81%
# Batch 70: Loss: 0.8146, Accuracy: 75.00%
# Batch 71: Loss: 0.7058, Accuracy: 79.69%
# Batch 72: Loss: 0.6575, Accuracy: 76.56%
# Batch 73: Loss: 0.6374, Accuracy: 76.56%
# Batch 74: Loss: 0.2863, Accuracy: 82.81%
# Batch 75: Loss: 0.7704, Accuracy: 82.81%
# Batch 76: Loss: 0.3632, Accuracy: 84.38%
# Batch 77: Loss: 0.6011, Accuracy: 81.25%
# Batch 78: Loss: 0.7645, Accuracy: 76.56%
# Batch 79: Loss: 0.6389, Accuracy: 84.38%
# Batch 80: Loss: 0.6152, Accuracy: 76.56%
# Batch 81: Loss: 0.4471, Accuracy: 84.38%
# Batch 82: Loss: 0.7308, Accuracy: 71.88%
# Batch 83: Loss: 0.5934, Accuracy: 81.25%
# Batch 84: Loss: 0.6194, Accuracy: 81.25%
# Batch 85: Loss: 0.6969, Accuracy: 70.31%
# Batch 86: Loss: 0.4643, Accuracy: 85.94%
# Batch 87: Loss: 0.8600, Accuracy: 79.69%
# Batch 88: Loss: 0.4226, Accuracy: 87.50%
# Batch 89: Loss: 0.6433, Accuracy: 78.12%
# Batch 90: Loss: 0.4655, Accuracy: 82.81%
# Batch 91: Loss: 0.5903, Accuracy: 78.12%
# Batch 92: Loss: 0.7388, Accuracy: 71.88%
# Batch 93: Loss: 0.8599, Accuracy: 70.31%
# Batch 94: Loss: 0.5032, Accuracy: 79.69%
# Batch 95: Loss: 0.4215, Accuracy: 82.81%
# Batch 96: Loss: 0.5444, Accuracy: 79.69%
# Batch 97: Loss: 0.5452, Accuracy: 81.25%
# Batch 98: Loss: 0.4985, Accuracy: 81.25%
# Batch 99: Loss: 0.2030, Accuracy: 92.19%
# Batch 100: Loss: 0.5525, Accuracy: 81.25%
# Batch 101: Loss: 0.4499, Accuracy: 85.94%
# Batch 102: Loss: 0.9123, Accuracy: 75.00%
# Batch 103: Loss: 0.6230, Accuracy: 82.81%
# Batch 104: Loss: 0.4617, Accuracy: 84.38%
# Batch 105: Loss: 0.3075, Accuracy: 89.06%
# Batch 106: Loss: 0.7921, Accuracy: 75.00%
# Batch 107: Loss: 0.4022, Accuracy: 84.38%
# Batch 108: Loss: 0.8262, Accuracy: 76.56%
# Batch 109: Loss: 0.6512, Accuracy: 81.25%
# Batch 110: Loss: 0.9572, Accuracy: 76.56%
# Batch 111: Loss: 0.6347, Accuracy: 81.25%
# Batch 112: Loss: 0.5608, Accuracy: 81.25%
# Batch 113: Loss: 0.6663, Accuracy: 78.12%
# Batch 114: Loss: 0.6823, Accuracy: 81.25%
# Batch 115: Loss: 0.4603, Accuracy: 87.50%
# Batch 116: Loss: 0.9924, Accuracy: 70.31%
# Batch 117: Loss: 0.6151, Accuracy: 84.38%
# Batch 118: Loss: 0.4250, Accuracy: 82.81%
# Batch 119: Loss: 0.8373, Accuracy: 73.44%
# Batch 120: Loss: 0.9405, Accuracy: 71.88%
# Batch 121: Loss: 0.3352, Accuracy: 87.50%
# Batch 122: Loss: 0.6619, Accuracy: 78.12%
# Batch 123: Loss: 0.6774, Accuracy: 76.56%
# Batch 124: Loss: 1.0146, Accuracy: 76.56%
# Batch 125: Loss: 0.6463, Accuracy: 82.81%
# Batch 126: Loss: 0.6169, Accuracy: 78.12%
# Batch 127: Loss: 0.5928, Accuracy: 78.12%
# Batch 128: Loss: 0.4344, Accuracy: 84.38%
# Batch 129: Loss: 0.4217, Accuracy: 81.25%
# Batch 130: Loss: 0.7914, Accuracy: 78.12%
# Batch 131: Loss: 0.7408, Accuracy: 76.56%
# Batch 132: Loss: 0.6087, Accuracy: 78.12%
# Batch 133: Loss: 0.8725, Accuracy: 71.88%
# Batch 134: Loss: 0.8076, Accuracy: 85.94%
# Batch 135: Loss: 0.7340, Accuracy: 78.12%
# Batch 136: Loss: 0.7266, Accuracy: 75.00%
# Batch 137: Loss: 0.7011, Accuracy: 81.25%
# Batch 138: Loss: 0.6449, Accuracy: 78.12%
# Batch 139: Loss: 0.4151, Accuracy: 79.69%
# Batch 140: Loss: 0.8757, Accuracy: 79.69%
# Batch 141: Loss: 0.4235, Accuracy: 89.06%
# Batch 142: Loss: 0.5325, Accuracy: 81.25%
# Batch 143: Loss: 0.4981, Accuracy: 82.81%
# Batch 144: Loss: 0.4853, Accuracy: 82.81%
# Batch 145: Loss: 0.6760, Accuracy: 81.25%
# Batch 146: Loss: 0.5722, Accuracy: 82.81%
# Batch 147: Loss: 0.6789, Accuracy: 82.81%
# Batch 148: Loss: 0.6627, Accuracy: 76.56%
# Batch 149: Loss: 0.5787, Accuracy: 84.38%
# Batch 150: Loss: 0.4740, Accuracy: 89.06%
# Batch 151: Loss: 0.5529, Accuracy: 81.25%
# Batch 152: Loss: 0.4357, Accuracy: 82.81%
# Batch 153: Loss: 0.6976, Accuracy: 81.25%
# Batch 154: Loss: 1.1050, Accuracy: 70.31%
# Batch 155: Loss: 0.4449, Accuracy: 90.62%
# Batch 156: Loss: 0.6953, Accuracy: 78.12%
# Batch 157: Loss: 0.4210, Accuracy: 68.75%
#
# Test set: Average loss: 0.6205, Accuracy: 8020/10000 (80%)
#
# Class 0: Accuracy: 82.00%
# Class 1: Accuracy: 76.10%
# Class 2: Accuracy: 70.60%
# Class 3: Accuracy: 63.80%
# Class 4: Accuracy: 80.40%
# Class 5: Accuracy: 83.00%
# Class 6: Accuracy: 89.60%
# Class 7: Accuracy: 73.30%
# Class 8: Accuracy: 91.90%
# Class 9: Accuracy: 91.30%

# %% [markdown]
# 移除残差连接

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

#定义网络模型
class BasicBlock(nn.Module):  # 定义一个没有残差连接的卷积块
    def __init__(self, in_planes, planes, stride=1):  # 构造函数
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)  # 定义第一个卷积层
        self.bn1 = nn.BatchNorm2d(planes)  # 批量归一化层
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)  # 定义第二个卷积层
        self.bn2 = nn.BatchNorm2d(planes)  # 批量归一化层

    def forward(self, x):  # 定义前向传播函数
        out = F.relu(self.bn1(self.conv1(x)))  # 应用第一层卷积和ReLU激活
        out = self.bn2(self.conv2(out))  # 应用第二层卷积
        out = F.relu(out)  # 直接应用ReLU激活
        return out

class ResNet(nn.Module):  # 定义没有残差连接的网络模型
    def __init__(self, block, num_blocks, num_classes=10):  # 构造函数
        super(ResNet, self).__init__()
        self.in_planes = 64  # 初始化输入通道数

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)  # 定义卷积层
        self.bn1 = nn.BatchNorm2d(64)  # 批量归一化层
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)  # 定义四个层
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)  # 全连接层

    def _make_layer(self, block, planes, num_blocks, stride):  # 创建由多个块组成的层
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:  # 循环创建每个块
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes  # 更新输入通道数
        return nn.Sequential(*layers)  # 返回包含所有块的顺序容器

    def forward(self, x):  # 前向传播
        out = F.relu(self.bn1(self.conv1(x)))  # 应用 Relu 激活函数
        out = self.layer1(out)  # 依次通过所有层
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)  # 应用平均池化减小空间维度
        out = out.view(out.size(0), -1)
        out = self.linear(out)  # 全连接层
        return out


# 定义ResNet-18使用新的BasicBlock类
num_blocks = [2, 2, 2, 2]  # ResNet-18的结构
model = ResNet(BasicBlock, num_blocks, num_classes=10)  # 实例化网络模型

# %%
criterion = nn.CrossEntropyLoss()

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

def train(model, device, train_loader, optimizer, epoch, criterion): #定义训练函数
    model.train()  #用于训练的模型，设置模型为训练模式
    running_loss = 0.0 #初始化损失和准确率的累计变量
    corrects = 0
    total = 0
    for batch_idx, (data, target) in enumerate(train_loader):#遍历数据加载器的每个批次
        data, target = data.to(device), target.to(device) #将数据和标签移动到指定设备
        optimizer.zero_grad() #梯度清空
        output = model(data)  #前向传播得到输出
        loss = criterion(output, target) #计算损失
        loss.backward()  #反向传播计算梯度
        optimizer.step()  #更新模型参数

        # 计算并累计准确率
        _, preds = torch.max(output, 1)
        corrects += torch.sum(preds == target.data)
        total += target.size(0)

        running_loss += loss.item() * data.size(0)  #累计损失

        # 只在batch_idx不为0且是100的倍数时打印
        if batch_idx != 0 and batch_idx % 100 == 0:
            avg_loss = running_loss / (batch_idx * data.size(0))  #打印损失和准确率
            acc = 100. * corrects / total
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}\tAcc: {:.2f}%'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), avg_loss, acc))
            running_loss = 0.0  #清零。重新累计
            corrects = 0
            total = 0

    return avg_loss, acc

# 假设有CUDA 设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)  #将模型移动到指定的设备

# 初始化列表来存储每个epoch的损失和准确率
train_losses2 = []
train_accs2 = []

# 训练模型
num_epochs = 5  #设置训练轮数

for epoch in range(1, num_epochs + 1): #遍历每个epoch
    avg_loss, acc = train(model, device, DataLoader(TensorDataset(train_data, train_labels), batch_size=64, shuffle=True), optimizer, epoch, criterion)
    train_losses2.append(avg_loss) #调用train函数进行训练，获取平均损失和准确率并添加到对应列表
    train_accs2.append(acc)

# 保存模型
torch.save(model.state_dict(), 'model2.pth')
# Out:
# Train Epoch: 1 [6400/50000 (13%)]	Loss: 1.944665	Acc: 26.53%
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 0.841266	Acc: 36.69%
# Train Epoch: 1 [19200/50000 (38%)]	Loss: 0.522672	Acc: 40.83%
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.382630	Acc: 43.73%
# Train Epoch: 1 [32000/50000 (64%)]	Loss: 0.277079	Acc: 48.80%
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.228359	Acc: 50.28%
# Train Epoch: 1 [44800/50000 (90%)]	Loss: 0.185738	Acc: 52.25%
# Train Epoch: 2 [6400/50000 (13%)]	Loss: 1.177527	Acc: 58.29%
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.550529	Acc: 59.83%
# Train Epoch: 2 [19200/50000 (38%)]	Loss: 0.367831	Acc: 60.12%
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.259043	Acc: 61.97%
# Train Epoch: 2 [32000/50000 (64%)]	Loss: 0.210059	Acc: 62.11%
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.167031	Acc: 64.05%
# Train Epoch: 2 [44800/50000 (90%)]	Loss: 0.138340	Acc: 65.50%
# Train Epoch: 3 [6400/50000 (13%)]	Loss: 0.904349	Acc: 68.24%
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.443481	Acc: 67.89%
# Train Epoch: 3 [19200/50000 (38%)]	Loss: 0.293593	Acc: 68.83%
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.211980	Acc: 69.75%
# Train Epoch: 3 [32000/50000 (64%)]	Loss: 0.168066	Acc: 70.83%
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.135459	Acc: 71.34%
# Train Epoch: 3 [44800/50000 (90%)]	Loss: 0.112947	Acc: 71.84%
# Train Epoch: 4 [6400/50000 (13%)]	Loss: 0.762396	Acc: 73.28%
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.354870	Acc: 75.17%
# Train Epoch: 4 [19200/50000 (38%)]	Loss: 0.226846	Acc: 76.78%
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.176300	Acc: 75.52%
# Train Epoch: 4 [32000/50000 (64%)]	Loss: 0.139768	Acc: 75.91%
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.113698	Acc: 76.11%
# Train Epoch: 4 [44800/50000 (90%)]	Loss: 0.098401	Acc: 75.89%
# Train Epoch: 5 [6400/50000 (13%)]	Loss: 0.601772	Acc: 79.47%
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.302745	Acc: 79.17%
# Train Epoch: 5 [19200/50000 (38%)]	Loss: 0.197908	Acc: 79.34%
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.152641	Acc: 79.31%
# Train Epoch: 5 [32000/50000 (64%)]	Loss: 0.118525	Acc: 79.42%
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.100299	Acc: 79.23%
# Train Epoch: 5 [44800/50000 (90%)]	Loss: 0.083440	Acc: 79.45%

# %%
# 确保train_losses和train_accs中的值是CPU张量或数值
train_accs2 = [acc.item() for acc in train_accs2]
# 训练结束后绘制曲线
plt.figure(figsize=(10, 5))  #创建窗口并规定图像大小

# 绘制损失曲线
plt.subplot(1, 2, 1)  #创建子图网格
plt.plot(train_losses2, label='Training Loss') #绘制训练损失曲线
plt.title('Training Loss over Epochs') #子图标题
plt.xlabel('Epoch')  #X轴标签
plt.ylabel('Loss')   #Y轴标签
plt.legend()  #显示图例

# 绘制准确率曲线
plt.subplot(1, 2, 2)
plt.plot(train_accs2, label='Training Accuracy')
plt.title('Training Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# 显示图形
plt.tight_layout()
plt.show()

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import torch
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset

losses2 = []  # 记录每个批次的损失
accuracies2 = []  # 记录每个批次的准确率

def test(model, device, test_loader, output_file):
    model.eval()  # 设置模型为评估模式
    test_loss = 0  # 初始化用于记录测试损失、正确预测数和总样本数的变量
    correct = 0
    total = 0
    preds = []
    
    

    # 记录每个类别的正确预测数和总样本数
    correct_per_class = [0] * 10  # 假设有10个类别
    total_per_class = [0] * 10
    
    with torch.no_grad():  # 不需要计算梯度
        for batch_idx, (data, target) in enumerate(test_loader):  # 遍历每个批次的数据
            data, target = data.to(device), target.to(device)  # 将数据转移到指定设备上
            output = model(data)  # 模型预测得到输出
            loss = criterion(output, target)  # 计算损失
            test_loss += loss.item()  # 累加损失
            
            # 计算批次的准确率
            _, predicted = torch.max(output, 1)  # 获取预测结果
            preds.extend([classes[i] for i in predicted.cpu().numpy()])  # 将预测类别转换为类别标签字符串，并添加到preds列表中
            
            total += target.size(0)  # 累加样本总数
            correct += (predicted == target).sum().item()  # 统计正确预测的样本数

            # 更新每个类别的正确预测数和总样本数
            for i in range(len(target)):
                label = target[i].item()
                correct_per_class[label] += (predicted[i] == target[i]).item()
                total_per_class[label] += 1
            
            # 计算每个批次的损失和准确率
            batch_loss = loss.item()
            batch_accuracy = 100 * (predicted == target).sum().item() / target.size(0)
            losses2.append(batch_loss)
            accuracies2.append(batch_accuracy)
            
            # 打印每个批次的损失和准确率
            print(f'Batch {batch_idx + 1}: Loss: {batch_loss:.4f}, Accuracy: {batch_accuracy:.2f}%')
    
    # 创建DataFrame并保存为CSV文件
    sorted_ids = list(range(1, len(test_data) + 1))
    sorted_ids.sort(key=lambda x: str(x))
    df = pd.DataFrame({'id': sorted_ids, 'label': preds})  # 第一列是id，第二列是预测的类别
    df.to_csv(output_file, index=False)  # 保存为CSV文件，不包含索引

    # 计算平均损失和准确率
    avg_loss = test_loss / len(test_loader)
    accuracy = 100 * correct / total

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(  # 打印平均loss和准确率
        avg_loss, correct, total, accuracy))
    
    # 打印每个类别的准确率
    for i in range(len(correct_per_class)):
        class_accuracy = 100 * correct_per_class[i] / total_per_class[i] if total_per_class[i] > 0 else 0
        print(f'Class {i}: Accuracy: {class_accuracy:.2f}%')

    # 绘制损失和准确率曲线
    plt.figure(figsize=(12, 5))
    
    # 绘制损失曲线
    plt.subplot(1, 2, 1)
    plt.plot(losses2, label='Loss', color='blue')
    plt.xlabel('Batch')
    plt.ylabel('Loss')
    plt.title('Loss Curve')
    plt.legend()
    
    # 绘制准确率曲线
    plt.subplot(1, 2, 2)
    plt.plot(accuracies2, label='Accuracy', color='orange')
    plt.xlabel('Batch')
    plt.ylabel('Accuracy (%)')
    plt.title('Accuracy Curve')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# 创建DataLoader
test_loader = DataLoader(TensorDataset(test_data, test_labels), batch_size=64, shuffle=False)

# 创建模型实例并加载训练好的模型
model = ResNet(BasicBlock, num_blocks, num_classes=10)
model.load_state_dict(torch.load('model2.pth'))
model.to(device)

# 测试模型并绘制损失和准确率曲线
test(model, device, test_loader, 'submission2.csv')
# Out:
# Batch 1: Loss: 0.8324, Accuracy: 65.62%
# Batch 2: Loss: 0.6094, Accuracy: 76.56%
# Batch 3: Loss: 0.8907, Accuracy: 68.75%
# Batch 4: Loss: 0.8004, Accuracy: 75.00%
# Batch 5: Loss: 0.7252, Accuracy: 76.56%
# Batch 6: Loss: 0.7154, Accuracy: 73.44%
# Batch 7: Loss: 0.8196, Accuracy: 68.75%
# Batch 8: Loss: 0.7027, Accuracy: 79.69%
# Batch 9: Loss: 0.6667, Accuracy: 78.12%
# Batch 10: Loss: 0.5477, Accuracy: 81.25%
# Batch 11: Loss: 0.8120, Accuracy: 71.88%
# Batch 12: Loss: 0.8884, Accuracy: 70.31%
# Batch 13: Loss: 0.9687, Accuracy: 60.94%
# Batch 14: Loss: 0.8132, Accuracy: 70.31%
# Batch 15: Loss: 0.7698, Accuracy: 76.56%
# Batch 16: Loss: 0.5432, Accuracy: 78.12%
# Batch 17: Loss: 0.8337, Accuracy: 70.31%
# Batch 18: Loss: 0.7751, Accuracy: 75.00%
# Batch 19: Loss: 0.5783, Accuracy: 84.38%
# Batch 20: Loss: 0.9042, Accuracy: 64.06%
# Batch 21: Loss: 0.6438, Accuracy: 78.12%
# Batch 22: Loss: 0.5946, Accuracy: 76.56%
# Batch 23: Loss: 0.7303, Accuracy: 73.44%
# Batch 24: Loss: 0.6048, Accuracy: 75.00%
# Batch 25: Loss: 0.7391, Accuracy: 75.00%
# Batch 26: Loss: 0.6438, Accuracy: 79.69%
# Batch 27: Loss: 0.6494, Accuracy: 79.69%
# Batch 28: Loss: 0.8775, Accuracy: 70.31%
# Batch 29: Loss: 0.6738, Accuracy: 76.56%
# Batch 30: Loss: 0.6694, Accuracy: 76.56%
# Batch 31: Loss: 0.9704, Accuracy: 70.31%
# Batch 32: Loss: 0.8163, Accuracy: 70.31%
# Batch 33: Loss: 0.6850, Accuracy: 79.69%
# Batch 34: Loss: 0.9916, Accuracy: 67.19%
# Batch 35: Loss: 0.8717, Accuracy: 67.19%
# Batch 36: Loss: 1.0399, Accuracy: 64.06%
# Batch 37: Loss: 0.7203, Accuracy: 76.56%
# Batch 38: Loss: 0.8090, Accuracy: 75.00%
# Batch 39: Loss: 0.5832, Accuracy: 78.12%
# Batch 40: Loss: 1.1365, Accuracy: 67.19%
# Batch 41: Loss: 0.6729, Accuracy: 79.69%
# Batch 42: Loss: 0.8075, Accuracy: 73.44%
# Batch 43: Loss: 0.8073, Accuracy: 71.88%
# Batch 44: Loss: 1.0627, Accuracy: 67.19%
# Batch 45: Loss: 0.9733, Accuracy: 68.75%
# Batch 46: Loss: 0.7061, Accuracy: 78.12%
# Batch 47: Loss: 0.8800, Accuracy: 70.31%
# Batch 48: Loss: 0.9840, Accuracy: 75.00%
# Batch 49: Loss: 0.6923, Accuracy: 71.88%
# Batch 50: Loss: 0.8676, Accuracy: 75.00%
# Batch 51: Loss: 0.7198, Accuracy: 75.00%
# Batch 52: Loss: 1.0158, Accuracy: 70.31%
# Batch 53: Loss: 1.0141, Accuracy: 65.62%
# Batch 54: Loss: 0.8697, Accuracy: 75.00%
# Batch 55: Loss: 1.0025, Accuracy: 65.62%
# Batch 56: Loss: 0.6573, Accuracy: 75.00%
# Batch 57: Loss: 0.8535, Accuracy: 73.44%
# Batch 58: Loss: 0.5607, Accuracy: 79.69%
# Batch 59: Loss: 0.7600, Accuracy: 78.12%
# Batch 60: Loss: 0.8186, Accuracy: 71.88%
# Batch 61: Loss: 0.7462, Accuracy: 67.19%
# Batch 62: Loss: 0.6015, Accuracy: 81.25%
# Batch 63: Loss: 0.7773, Accuracy: 75.00%
# Batch 64: Loss: 0.8301, Accuracy: 73.44%
# Batch 65: Loss: 0.9707, Accuracy: 73.44%
# Batch 66: Loss: 0.5692, Accuracy: 79.69%
# Batch 67: Loss: 0.7901, Accuracy: 71.88%
# Batch 68: Loss: 0.7359, Accuracy: 76.56%
# Batch 69: Loss: 0.6632, Accuracy: 76.56%
# Batch 70: Loss: 0.6560, Accuracy: 79.69%
# Batch 71: Loss: 0.8161, Accuracy: 71.88%
# Batch 72: Loss: 1.0062, Accuracy: 68.75%
# Batch 73: Loss: 0.7029, Accuracy: 75.00%
# Batch 74: Loss: 0.6884, Accuracy: 78.12%
# Batch 75: Loss: 0.7189, Accuracy: 76.56%
# Batch 76: Loss: 0.5487, Accuracy: 75.00%
# Batch 77: Loss: 0.8005, Accuracy: 73.44%
# Batch 78: Loss: 0.9576, Accuracy: 68.75%
# Batch 79: Loss: 0.8657, Accuracy: 73.44%
# Batch 80: Loss: 0.9394, Accuracy: 65.62%
# Batch 81: Loss: 0.5870, Accuracy: 85.94%
# Batch 82: Loss: 0.8219, Accuracy: 71.88%
# Batch 83: Loss: 0.6219, Accuracy: 75.00%
# Batch 84: Loss: 0.6746, Accuracy: 79.69%
# Batch 85: Loss: 0.6398, Accuracy: 82.81%
# Batch 86: Loss: 0.7353, Accuracy: 75.00%
# Batch 87: Loss: 0.9355, Accuracy: 70.31%
# Batch 88: Loss: 0.7997, Accuracy: 73.44%
# Batch 89: Loss: 0.8534, Accuracy: 67.19%
# Batch 90: Loss: 0.5291, Accuracy: 78.12%
# Batch 91: Loss: 0.6059, Accuracy: 76.56%
# Batch 92: Loss: 0.9026, Accuracy: 70.31%
# Batch 93: Loss: 0.9053, Accuracy: 65.62%
# Batch 94: Loss: 0.9633, Accuracy: 62.50%
# Batch 95: Loss: 0.8785, Accuracy: 67.19%
# Batch 96: Loss: 0.6629, Accuracy: 76.56%
# Batch 97: Loss: 0.7899, Accuracy: 70.31%
# Batch 98: Loss: 0.7388, Accuracy: 75.00%
# Batch 99: Loss: 0.4415, Accuracy: 79.69%
# Batch 100: Loss: 0.8120, Accuracy: 76.56%
# Batch 101: Loss: 0.6105, Accuracy: 79.69%
# Batch 102: Loss: 0.9387, Accuracy: 67.19%
# Batch 103: Loss: 0.7900, Accuracy: 73.44%
# Batch 104: Loss: 0.7101, Accuracy: 76.56%
# Batch 105: Loss: 0.6035, Accuracy: 78.12%
# Batch 106: Loss: 0.9466, Accuracy: 70.31%
# Batch 107: Loss: 0.6475, Accuracy: 78.12%
# Batch 108: Loss: 0.8488, Accuracy: 71.88%
# Batch 109: Loss: 0.8636, Accuracy: 71.88%
# Batch 110: Loss: 0.8629, Accuracy: 75.00%
# Batch 111: Loss: 0.5672, Accuracy: 75.00%
# Batch 112: Loss: 0.6181, Accuracy: 76.56%
# Batch 113: Loss: 0.7750, Accuracy: 67.19%
# Batch 114: Loss: 0.6085, Accuracy: 79.69%
# Batch 115: Loss: 0.6225, Accuracy: 79.69%
# Batch 116: Loss: 0.9570, Accuracy: 68.75%
# Batch 117: Loss: 0.9390, Accuracy: 70.31%
# Batch 118: Loss: 0.6599, Accuracy: 78.12%
# Batch 119: Loss: 0.6500, Accuracy: 76.56%
# Batch 120: Loss: 0.8021, Accuracy: 71.88%
# Batch 121: Loss: 0.6835, Accuracy: 75.00%
# Batch 122: Loss: 1.0328, Accuracy: 67.19%
# Batch 123: Loss: 0.9096, Accuracy: 67.19%
# Batch 124: Loss: 0.8049, Accuracy: 71.88%
# Batch 125: Loss: 0.6152, Accuracy: 79.69%
# Batch 126: Loss: 0.6519, Accuracy: 81.25%
# Batch 127: Loss: 0.7840, Accuracy: 68.75%
# Batch 128: Loss: 0.7393, Accuracy: 76.56%
# Batch 129: Loss: 0.7913, Accuracy: 71.88%
# Batch 130: Loss: 0.7742, Accuracy: 71.88%
# Batch 131: Loss: 0.7939, Accuracy: 73.44%
# Batch 132: Loss: 0.7573, Accuracy: 75.00%
# Batch 133: Loss: 0.8875, Accuracy: 70.31%
# Batch 134: Loss: 0.8161, Accuracy: 75.00%
# Batch 135: Loss: 0.8778, Accuracy: 75.00%
# Batch 136: Loss: 0.9061, Accuracy: 68.75%
# Batch 137: Loss: 1.0427, Accuracy: 68.75%
# Batch 138: Loss: 0.8265, Accuracy: 68.75%
# Batch 139: Loss: 0.6451, Accuracy: 76.56%
# Batch 140: Loss: 0.7509, Accuracy: 76.56%
# Batch 141: Loss: 0.7407, Accuracy: 73.44%
# Batch 142: Loss: 0.5879, Accuracy: 78.12%
# Batch 143: Loss: 0.8104, Accuracy: 70.31%
# Batch 144: Loss: 0.6573, Accuracy: 75.00%
# Batch 145: Loss: 0.9796, Accuracy: 73.44%
# Batch 146: Loss: 0.7531, Accuracy: 76.56%
# Batch 147: Loss: 0.8289, Accuracy: 71.88%
# Batch 148: Loss: 0.9079, Accuracy: 65.62%
# Batch 149: Loss: 0.7573, Accuracy: 81.25%
# Batch 150: Loss: 0.5502, Accuracy: 81.25%
# Batch 151: Loss: 0.4583, Accuracy: 84.38%
# Batch 152: Loss: 0.6419, Accuracy: 71.88%
# Batch 153: Loss: 1.0431, Accuracy: 65.62%
# Batch 154: Loss: 0.9954, Accuracy: 70.31%
# Batch 155: Loss: 0.7001, Accuracy: 81.25%
# Batch 156: Loss: 0.9364, Accuracy: 71.88%
# Batch 157: Loss: 0.6876, Accuracy: 75.00%
#
# Test set: Average loss: 0.7758, Accuracy: 7373/10000 (74%)
#
# Class 0: Accuracy: 85.30%
# Class 1: Accuracy: 90.10%
# Class 2: Accuracy: 73.70%
# Class 3: Accuracy: 44.80%
# Class 4: Accuracy: 78.30%
# Class 5: Accuracy: 56.90%
# Class 6: Accuracy: 91.50%
# Class 7: Accuracy: 68.10%
# Class 8: Accuracy: 80.00%
# Class 9: Accuracy: 68.60%

# %%
import matplotlib.pyplot as plt

# # 确保train_losses1, train_losses2, train_accs1, train_accs2中的值是CPU张量或数值
# train_losses = [loss.item() for loss in train_losses]
# train_losses2 = [loss.item() for loss in train_losses2]
# train_accs = [acc.item() for acc in train_accs]
# train_accs2 = [acc.item() for acc in train_accs2]

# 训练结束后绘制曲线
plt.figure(figsize=(12, 5))  # 创建窗口并规定图像大小

# 绘制损失曲线
plt.subplot(1, 2, 1)  # 创建子图网格
plt.plot(train_losses, label='Train Loss 1', color='blue')  # 绘制第一组训练损失曲线
plt.plot(train_losses2, label='Train Loss 2', color='orange')  # 绘制第二组训练损失曲线
plt.title('Training Loss over Epochs')  # 子图标题
plt.xlabel('Epoch')  # X轴标签
plt.ylabel('Loss')  # Y轴标签
plt.legend()  # 显示图例

# 绘制准确率曲线
plt.subplot(1, 2, 2)
plt.plot(train_accs, label='Train Accuracy 1', color='blue')  # 绘制第一组训练准确率曲线
plt.plot(train_accs2, label='Train Accuracy 2', color='orange')  # 绘制第二组训练准确率曲线
plt.title('Training Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# 显示图形
plt.tight_layout()
plt.show()

# %%
# 绘制损失和准确率曲线
plt.figure(figsize=(12, 5))
    
# 绘制损失曲线
plt.subplot(1, 2, 1)
plt.plot(losses1, label='Test Loss 1', color='blue')  # 绘制第一组训练损失曲线
plt.plot(losses2, label='Test Loss 2', color='orange')
plt.xlabel('Batch')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
    
# 绘制准确率曲线
plt.subplot(1, 2, 2)
plt.plot(accuracies1, label='Test Accuracy 1', color='blue')
plt.plot(accuracies2, label='Test Accuracy 2', color='orange')
plt.xlabel('Batch')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Curve')
plt.legend()
    
plt.tight_layout()
plt.show()
